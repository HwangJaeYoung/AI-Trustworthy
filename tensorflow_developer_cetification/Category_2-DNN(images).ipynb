# %%
# 마지막 출력층
# Dense(1, activation='sigmoid') => loss='binary_crossentropy'
# Dense(2이상, activation='softmax') => loss='categorical_crossentropy'(원핫O)
# or 'sparse_categorical_crossentropy'(원핫X)

# %%
import numpy as np
import tensorflow as tf

from tensorflow.keras.layers import Dense, Flatten
from tensorflow.keras.models import Sequential
from tensorflow.keras.callbacks import ModelCheckpoint

# %%
fashion_mnist = tf.keras.datasets.fashion_mnist

# %%
(x_train, y_train), (x_valid, y_valid) = fashion_mnist.load_data()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-labels-idx1-ubyte.gz
# 32768/29515 [=================================] - 0s 0us/step
# 40960/29515 [=========================================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-images-idx3-ubyte.gz
# 26427392/26421880 [==============================] - 1s 0us/step
# 26435584/26421880 [==============================] - 1s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-labels-idx1-ubyte.gz
# 16384/5148 [===============================================================================================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-images-idx3-ubyte.gz
# 4423680/4422102 [==============================] - 0s 0us/step
# 4431872/4422102 [==============================] - 0s 0us/step

# %%
x_train.shape, x_valid.shape
# Out:
# ((60000, 28, 28), (10000, 28, 28))

# %%
y_train.shape, y_valid.shape
# Out:
# ((60000,), (10000,))

# %%
x_train.min(), x_train.max()
# Out:
# (0, 255)

# %%
x_train = x_train / 255.0
x_valid = x_valid / 255.0

# %%
x_train.min(), x_train.max()
# Out:
# (0.0, 1.0)

# %%
tf.keras.backend.set_floatx('float64')

# %%
model = Sequential([
    # Flatten으로 shape 펼치기
    Flatten(input_shape=(28, 28)),
    # Dense Layer
    Dense(1024, activation='relu'),
    Dense(512, activation='relu'),
    Dense(256, activation='relu'),
    Dense(128, activation='relu'),
    Dense(64, activation='relu'),
    # Classification을 위한 Softmax 
    Dense(10, activation='softmax'),
])
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  flatten (Flatten)           (None, 784)               0
#
#  dense (Dense)               (None, 1024)              803840
#
#  dense_1 (Dense)             (None, 512)               524800
#
#  dense_2 (Dense)             (None, 256)               131328
#
#  dense_3 (Dense)             (None, 128)               32896
#
#  dense_4 (Dense)             (None, 64)                8256
#
#  dense_5 (Dense)             (None, 10)                650
#
# =================================================================
# Total params: 1,501,770
# Trainable params: 1,501,770
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['acc'])

# %%
checkpoint_path = "my_checkpoint.ckpt"
checkpoint = ModelCheckpoint(filepath=checkpoint_path, 
                             save_weights_only=True, 
                             save_best_only=True, 
                             monitor='val_loss', 
                             verbose=1)

# %%
history = model.fit(x_train, y_train,
                    validation_data=(x_valid, y_valid),
                    epochs=20,
                    callbacks=[checkpoint],
                   )
# Out:
# Epoch 1/20
# 1869/1875 [============================>.] - ETA: 0s - loss: 0.5028 - acc: 0.8201
# Epoch 00001: val_loss improved from inf to 0.48103, saving model to my_checkpoint.ckpt
# 1875/1875 [==============================] - 21s 10ms/step - loss: 0.5023 - acc: 0.8202 - val_loss: 0.4810 - val_acc: 0.8210
# Epoch 2/20
# 1869/1875 [============================>.] - ETA: 0s - loss: 0.3799 - acc: 0.8625
# Epoch 00002: val_loss improved from 0.48103 to 0.43835, saving model to my_checkpoint.ckpt
# 1875/1875 [==============================] - 13s 7ms/step - loss: 0.3799 - acc: 0.8625 - val_loss: 0.4383 - val_acc: 0.8425
# Epoch 3/20
# 1870/1875 [============================>.] - ETA: 0s - loss: 0.3417 - acc: 0.8757
# Epoch 00003: val_loss improved from 0.43835 to 0.37346, saving model to my_checkpoint.ckpt
# 1875/1875 [==============================] - 13s 7ms/step - loss: 0.3418 - acc: 0.8758 - val_loss: 0.3735 - val_acc: 0.8647
# Epoch 4/20
# 1872/1875 [============================>.] - ETA: 0s - loss: 0.3186 - acc: 0.8831
# Epoch 00004: val_loss improved from 0.37346 to 0.37204, saving model to my_checkpoint.ckpt
# 1875/1875 [==============================] - 13s 7ms/step - loss: 0.3188 - acc: 0.8831 - val_loss: 0.3720 - val_acc: 0.8710
# Epoch 5/20
# 1867/1875 [============================>.] - ETA: 0s - loss: 0.2966 - acc: 0.8913
# Epoch 00005: val_loss did not improve from 0.37204
# 1875/1875 [==============================] - 13s 7ms/step - loss: 0.2966 - acc: 0.8914 - val_loss: 0.3773 - val_acc: 0.8624
# Epoch 6/20
# 1873/1875 [============================>.] - ETA: 0s - loss: 0.2852 - acc: 0.8954
# Epoch 00006: val_loss improved from 0.37204 to 0.34565, saving model to my_checkpoint.ckpt
# 1875/1875 [==============================] - 15s 8ms/step - loss: 0.2851 - acc: 0.8954 - val_loss: 0.3456 - val_acc: 0.8756
# Epoch 7/20
# 1871/1875 [============================>.] - ETA: 0s - loss: 0.2697 - acc: 0.8994
# Epoch 00007: val_loss improved from 0.34565 to 0.34142, saving model to my_checkpoint.ckpt
# 1875/1875 [==============================] - 13s 7ms/step - loss: 0.2696 - acc: 0.8994 - val_loss: 0.3414 - val_acc: 0.8830
# Epoch 8/20
# 1874/1875 [============================>.] - ETA: 0s - loss: 0.2585 - acc: 0.9045
# Epoch 00008: val_loss improved from 0.34142 to 0.33491, saving model to my_checkpoint.ckpt
# 1875/1875 [==============================] - 13s 7ms/step - loss: 0.2584 - acc: 0.9045 - val_loss: 0.3349 - val_acc: 0.8871
# Epoch 9/20
# 1872/1875 [============================>.] - ETA: 0s - loss: 0.2514 - acc: 0.9076
# Epoch 00009: val_loss did not improve from 0.33491
# 1875/1875 [==============================] - 13s 7ms/step - loss: 0.2515 - acc: 0.9075 - val_loss: 0.3410 - val_acc: 0.8846
# Epoch 10/20
# 1874/1875 [============================>.] - ETA: 0s - loss: 0.2414 - acc: 0.9104
# Epoch 00010: val_loss did not improve from 0.33491
# 1875/1875 [==============================] - 13s 7ms/step - loss: 0.2413 - acc: 0.9104 - val_loss: 0.3536 - val_acc: 0.8746
# Epoch 11/20
# 1871/1875 [============================>.] - ETA: 0s - loss: 0.2342 - acc: 0.9133
# Epoch 00011: val_loss did not improve from 0.33491
# 1875/1875 [==============================] - 13s 7ms/step - loss: 0.2342 - acc: 0.9133 - val_loss: 0.3457 - val_acc: 0.8805
# Epoch 12/20
# 1868/1875 [============================>.] - ETA: 0s - loss: 0.2214 - acc: 0.9164
# Epoch 00012: val_loss did not improve from 0.33491
# 1875/1875 [==============================] - 13s 7ms/step - loss: 0.2215 - acc: 0.9164 - val_loss: 0.4143 - val_acc: 0.8814
# Epoch 13/20
# 1871/1875 [============================>.] - ETA: 0s - loss: 0.2182 - acc: 0.9192
# Epoch 00013: val_loss did not improve from 0.33491
# 1875/1875 [==============================] - 13s 7ms/step - loss: 0.2184 - acc: 0.9191 - val_loss: 0.3709 - val_acc: 0.8843
# Epoch 14/20
# 1868/1875 [============================>.] - ETA: 0s - loss: 0.2110 - acc: 0.9210
# Epoch 00014: val_loss did not improve from 0.33491
# 1875/1875 [==============================] - 14s 7ms/step - loss: 0.2111 - acc: 0.9210 - val_loss: 0.3425 - val_acc: 0.8918
# Epoch 15/20
# 1868/1875 [============================>.] - ETA: 0s - loss: 0.2054 - acc: 0.9210
# Epoch 00015: val_loss did not improve from 0.33491
# 1875/1875 [==============================] - 14s 7ms/step - loss: 0.2053 - acc: 0.9210 - val_loss: 0.3426 - val_acc: 0.8849
# Epoch 16/20
# 1868/1875 [============================>.] - ETA: 0s - loss: 0.1966 - acc: 0.9262
# Epoch 00016: val_loss did not improve from 0.33491
# 1875/1875 [==============================] - 13s 7ms/step - loss: 0.1967 - acc: 0.9261 - val_loss: 0.3505 - val_acc: 0.8868
# Epoch 17/20
# 1874/1875 [============================>.] - ETA: 0s - loss: 0.1927 - acc: 0.9275
# Epoch 00017: val_loss did not improve from 0.33491
# 1875/1875 [==============================] - 13s 7ms/step - loss: 0.1927 - acc: 0.9275 - val_loss: 0.3904 - val_acc: 0.8861
# Epoch 18/20
# 1870/1875 [============================>.] - ETA: 0s - loss: 0.1904 - acc: 0.9285
# Epoch 00018: val_loss did not improve from 0.33491
# 1875/1875 [==============================] - 13s 7ms/step - loss: 0.1906 - acc: 0.9285 - val_loss: 0.3548 - val_acc: 0.8914
# Epoch 19/20
# 1870/1875 [============================>.] - ETA: 0s - loss: 0.1829 - acc: 0.9314
# Epoch 00019: val_loss did not improve from 0.33491
# 1875/1875 [==============================] - 13s 7ms/step - loss: 0.1829 - acc: 0.9314 - val_loss: 0.3761 - val_acc: 0.8883
# Epoch 20/20
# 1871/1875 [============================>.] - ETA: 0s - loss: 0.1816 - acc: 0.9313
# Epoch 00020: val_loss did not improve from 0.33491
# 1875/1875 [==============================] - 13s 7ms/step - loss: 0.1815 - acc: 0.9314 - val_loss: 0.3659 - val_acc: 0.8893

# %%
# checkpoint 를 저장한 파일명을 입력합니다.
model.load_weights(checkpoint_path)

# %%
model.evaluate(x_valid, y_valid)
# Out:
# 313/313 [==============================] - 1s 5ms/step - loss: 0.3349 - acc: 0.8871
# [0.3349081249475479, 0.8871]
