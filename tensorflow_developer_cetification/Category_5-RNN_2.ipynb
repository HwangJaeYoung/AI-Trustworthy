# %%
import urllib
import pandas as pd
import tensorflow as tf
from tensorflow.keras.layers import Dense, Conv1D, LSTM, Bidirectional
from tensorflow.keras.models import Sequential
from tensorflow.keras.callbacks import ModelCheckpoint

# 아래 2줄 코드는 넣지 말아 주세요!!!
url = 'https://www.dropbox.com/s/eduk281didil1km/Weekly_U.S.Diesel_Retail_Prices.csv?dl=1'
urllib.request.urlretrieve(url, 'Weekly_U.S.Diesel_Retail_Prices.csv')
# Out:
# ('Weekly_U.S.Diesel_Retail_Prices.csv',
#  <http.client.HTTPMessage at 0x7f6b67c615d0>)

# %%
# This function normalizes the dataset using min max scaling.
# DO NOT CHANGE THIS CODE
def normalize_series(data, min, max):
    data = data - min
    data = data / max
    return data

# %%
# DO NOT CHANGE THIS.
def windowed_dataset(series, batch_size, n_past=10, n_future=10, shift=1):
    ds = tf.data.Dataset.from_tensor_slices(series)
    ds = ds.window(size=n_past + n_future, shift=shift, drop_remainder=True)
    ds = ds.flat_map(lambda w: w.batch(n_past + n_future))
    ds = ds.map(lambda w: (w[:n_past], w[n_past:]))
    return ds.batch(batch_size).prefetch(1)

# %%
df = pd.read_csv('Weekly_U.S.Diesel_Retail_Prices.csv', infer_datetime_format=True, index_col='Week of', header=0)
df.head(20)
# Out:
#             Weekly U.S. No 2 Diesel Retail Prices Dollars per Gallon
# Week of
# 1994-03-21                                              1.106
# 1994-03-28                                              1.107
# 1994-04-04                                              1.109
# 1994-04-11                                              1.108
# 1994-04-18                                              1.105
# 1994-04-25                                              1.106
# 1994-05-02                                              1.104
# 1994-05-09                                              1.101
# 1994-05-16                                              1.099
# 1994-05-23                                              1.099
# 1994-05-30                                              1.098
# 1994-06-06                                              1.101
# 1994-06-13                                              1.098
# 1994-06-20                                              1.103
# 1994-06-27                                              1.108
# 1994-07-04                                              1.109
# 1994-07-11                                              1.110
# 1994-07-18                                              1.111
# 1994-07-25                                              1.111
# 1994-08-01                                              1.116

# %%
# 특성 정의
N_FEATURES = len(df.columns)
N_FEATURES
# Out:
# 1

# %%
# 정규화 코드
data = df.values
data = normalize_series(data, data.min(axis=0), data.max(axis=0))

# 데이터 분할
SPLIT_TIME = int(len(data) * 0.8) # DO NOT CHANGE THIS
x_train = data[:SPLIT_TIME]
x_valid = data[SPLIT_TIME:]

# %%
BATCH_SIZE = 32  # 배치사이즈
N_PAST = 10      # 과거 데이터 (X)
N_FUTURE = 10    # 미래 데이터 (Y)
SHIFT = 1        # SHIFT

# %%
train_set = windowed_dataset(series=x_train, batch_size=BATCH_SIZE,
                             n_past=N_PAST, n_future=N_FUTURE,
                             shift=SHIFT)

valid_set = windowed_dataset(series=x_valid, batch_size=BATCH_SIZE,
                             n_past=N_PAST, n_future=N_FUTURE,
                             shift=SHIFT)

# %%
model = tf.keras.models.Sequential([
    Conv1D(filters=32, kernel_size=5, padding='causal', activation='relu', input_shape=[N_PAST, 1]),
    Bidirectional(LSTM(32, return_sequences=True)),
    Bidirectional(LSTM(32, return_sequences=True)),
    Dense(32, activation='relu'),
    Dense(16, activation='relu'),
    Dense(N_FEATURES)
])

# %%
checkpoint_path = 'model/my_checkpoint.ckpt'
checkpoint = ModelCheckpoint(filepath=checkpoint_path,
                             save_weights_only=True,
                             save_best_only=True,
                             monitor='val_mae',
                             verbose=1)

# %%
optimizer = tf.keras.optimizers.Adam(0.0001)
model.compile(optimizer=optimizer, loss=tf.keras.losses.Huber(), metrics=['mae'])

# %%
model.fit(train_set,
          validation_data=(valid_set),
          epochs=100,
          callbacks=[checkpoint])
# Out:
# Epoch 1/100
#      32/Unknown - 23s 13ms/step - loss: 0.0494 - mae: 0.2374
# Epoch 00001: val_mae improved from inf to 0.32176, saving model to model/my_checkpoint.ckpt
# 35/35 [==============================] - 25s 68ms/step - loss: 0.0529 - mae: 0.2522 - val_loss: 0.0538 - val_mae: 0.3218
# Epoch 2/100
# 35/35 [==============================] - ETA: 0s - loss: 0.0368 - mae: 0.1993
# Epoch 00002: val_mae improved from 0.32176 to 0.25249, saving model to model/my_checkpoint.ckpt
# 35/35 [==============================] - 1s 17ms/step - loss: 0.0368 - mae: 0.1993 - val_loss: 0.0337 - val_mae: 0.2525
# Epoch 3/100
# 35/35 [==============================] - ETA: 0s - loss: 0.0213 - mae: 0.1519
# Epoch 00003: val_mae improved from 0.25249 to 0.15755, saving model to model/my_checkpoint.ckpt
# 35/35 [==============================] - 1s 15ms/step - loss: 0.0213 - mae: 0.1519 - val_loss: 0.0141 - val_mae: 0.1576
# Epoch 4/100
# 33/35 [===========================>..] - ETA: 0s - loss: 0.0102 - mae: 0.1166
# Epoch 00004: val_mae improved from 0.15755 to 0.06382, saving model to model/my_checkpoint.ckpt
# 35/35 [==============================] - 1s 15ms/step - loss: 0.0098 - mae: 0.1136 - val_loss: 0.0032 - val_mae: 0.0638
# Epoch 5/100
# 33/35 [===========================>..] - ETA: 0s - loss: 0.0071 - mae: 0.1040
# Epoch 00005: val_mae improved from 0.06382 to 0.04611, saving model to model/my_checkpoint.ckpt
# 35/35 [==============================] - 1s 16ms/step - loss: 0.0068 - mae: 0.1013 - val_loss: 0.0017 - val_mae: 0.0461
# Epoch 6/100
# 32/35 [==========================>...] - ETA: 0s - loss: 0.0063 - mae: 0.0975
# Epoch 00006: val_mae improved from 0.04611 to 0.04469, saving model to model/my_checkpoint.ckpt
# 35/35 [==============================] - 1s 16ms/step - loss: 0.0060 - mae: 0.0946 - val_loss: 0.0016 - val_mae: 0.0447
# Epoch 7/100
# 32/35 [==========================>...] - ETA: 0s - loss: 0.0050 - mae: 0.0858
# Epoch 00007: val_mae improved from 0.04469 to 0.04324, saving model to model/my_checkpoint.ckpt
# 35/35 [==============================] - 1s 16ms/step - loss: 0.0048 - mae: 0.0836 - val_loss: 0.0015 - val_mae: 0.0432
# Epoch 8/100
# 33/35 [===========================>..] - ETA: 0s - loss: 0.0038 - mae: 0.0735
# Epoch 00008: val_mae improved from 0.04324 to 0.04198, saving model to model/my_checkpoint.ckpt
# 35/35 [==============================] - 1s 16ms/step - loss: 0.0038 - mae: 0.0728 - val_loss: 0.0014 - val_mae: 0.0420
# Epoch 9/100
# 31/35 [=========================>....] - ETA: 0s - loss: 0.0031 - mae: 0.0646
# Epoch 00009: val_mae improved from 0.04198 to 0.04087, saving model to model/my_checkpoint.ckpt
# 35/35 [==============================] - 1s 16ms/step - loss: 0.0030 - mae: 0.0635 - val_loss: 0.0014 - val_mae: 0.0409
# Epoch 10/100
# 34/35 [============================>.] - ETA: 0s - loss: 0.0026 - mae: 0.0567
# Epoch 00010: val_mae improved from 0.04087 to 0.03987, saving model to model/my_checkpoint.ckpt
# 35/35 [==============================] - 1s 16ms/step - loss: 0.0026 - mae: 0.0562 - val_loss: 0.0013 - val_mae: 0.0399
# Epoch 11/100
# 34/35 [============================>.] - ETA: 0s - loss: 0.0023 - mae: 0.0513
# Epoch 00011: val_mae improved from 0.03987 to 0.03887, saving model to model/my_checkpoint.ckpt
# 35/35 [==============================] - 1s 15ms/step - loss: 0.0023 - mae: 0.0510 - val_loss: 0.0012 - val_mae: 0.0389
# Epoch 12/100
# 31/35 [=========================>....] - ETA: 0s - loss: 0.0021 - mae: 0.0472
# Epoch 00012: val_mae improved from 0.03887 to 0.03787, saving model to model/my_checkpoint.ckpt
# 35/35 [==============================] - 1s 16ms/step - loss: 0.0021 - mae: 0.0474 - val_loss: 0.0012 - val_mae: 0.0379
# Epoch 13/100
# 34/35 [============================>.] - ETA: 0s - loss: 0.0020 - mae: 0.0453
# Epoch 00013: val_mae improved from 0.03787 to 0.03684, saving model to model/my_checkpoint.ckpt
# 35/35 [==============================] - 1s 16ms/step - loss: 0.0020 - mae: 0.0450 - val_loss: 0.0011 - val_mae: 0.0368
# Epoch 14/100
# 32/35 [==========================>...] - ETA: 0s - loss: 0.0019 - mae: 0.0427
# Epoch 00014: val_mae improved from 0.03684 to 0.03588, saving model to model/my_checkpoint.ckpt
# 35/35 [==============================] - 1s 16ms/step - loss: 0.0019 - mae: 0.0433 - val_loss: 0.0011 - val_mae: 0.0359
# Epoch 15/100
# 33/35 [===========================>..] - ETA: 0s - loss: 0.0018 - mae: 0.0412
# Epoch 00015: val_mae improved from 0.03588 to 0.03487, saving model to model/my_checkpoint.ckpt
# 35/35 [==============================] - 1s 15ms/step - loss: 0.0019 - mae: 0.0421 - val_loss: 0.0010 - val_mae: 0.0349
# Epoch 16/100
# 32/35 [==========================>...] - ETA: 0s - loss: 0.0018 - mae: 0.0405
# Epoch 00016: val_mae improved from 0.03487 to 0.03400, saving model to model/my_checkpoint.ckpt
# 35/35 [==============================] - 1s 16ms/step - loss: 0.0018 - mae: 0.0411 - val_loss: 0.0010 - val_mae: 0.0340
# Epoch 17/100
# 32/35 [==========================>...] - ETA: 0s - loss: 0.0017 - mae: 0.0398
# Epoch 00017: val_mae improved from 0.03400 to 0.03315, saving model to model/my_checkpoint.ckpt
# 35/35 [==============================] - 1s 17ms/step - loss: 0.0018 - mae: 0.0404 - val_loss: 9.6271e-04 - val_mae: 0.0331
# Epoch 18/100
# 34/35 [============================>.] - ETA: 0s - loss: 0.0017 - mae: 0.0398
# Epoch 00018: val_mae improved from 0.03315 to 0.03241, saving model to model/my_checkpoint.ckpt
# 35/35 [==============================] - 1s 16ms/step - loss: 0.0017 - mae: 0.0397 - val_loss: 9.3037e-04 - val_mae: 0.0324
# Epoch 19/100
# 32/35 [==========================>...] - ETA: 0s - loss: 0.0017 - mae: 0.0385
# Epoch 00019: val_mae improved from 0.03241 to 0.03175, saving model to model/my_checkpoint.ckpt
# 35/35 [==============================] - 1s 16ms/step - loss: 0.0017 - mae: 0.0391 - val_loss: 9.0253e-04 - val_mae: 0.0317
# Epoch 20/100
# 32/35 [==========================>...] - ETA: 0s - loss: 0.0016 - mae: 0.0380
# Epoch 00020: val_mae improved from 0.03175 to 0.03118, saving model to model/my_checkpoint.ckpt
# 35/35 [==============================] - 1s 16ms/step - loss: 0.0017 - mae: 0.0386 - val_loss: 8.7933e-04 - val_mae: 0.0312
# Epoch 21/100
# 33/35 [===========================>..] - ETA: 0s - loss: 0.0016 - mae: 0.0371
# Epoch 00021: val_mae improved from 0.03118 to 0.03067, saving model to model/my_checkpoint.ckpt
# 35/35 [==============================] - 1s 16ms/step - loss: 0.0016 - mae: 0.0382 - val_loss: 8.5944e-04 - val_mae: 0.0307
# Epoch 22/100
# 33/35 [===========================>..] - ETA: 0s - loss: 0.0016 - mae: 0.0367
# Epoch 00022: val_mae improved from 0.03067 to 0.03022, saving model to model/my_checkpoint.ckpt
# 35/35 [==============================] - 1s 16ms/step - loss: 0.0016 - mae: 0.0378 - val_loss: 8.4291e-04 - val_mae: 0.0302
# Epoch 23/100
# 33/35 [===========================>..] - ETA: 0s - loss: 0.0015 - mae: 0.0363
# Epoch 00023: val_mae improved from 0.03022 to 0.02984, saving model to model/my_checkpoint.ckpt
# 35/35 [==============================] - 1s 16ms/step - loss: 0.0016 - mae: 0.0374 - val_loss: 8.2879e-04 - val_mae: 0.0298
# Epoch 24/100
# 31/35 [=========================>....] - ETA: 0s - loss: 0.0016 - mae: 0.0372
# Epoch 00024: val_mae improved from 0.02984 to 0.02952, saving model to model/my_checkpoint.ckpt
# 35/35 [==============================] - 1s 16ms/step - loss: 0.0016 - mae: 0.0371 - val_loss: 8.1698e-04 - val_mae: 0.0295
# Epoch 25/100
# 35/35 [==============================] - ETA: 0s - loss: 0.0016 - mae: 0.0369
# Epoch 00025: val_mae improved from 0.02952 to 0.02925, saving model to model/my_checkpoint.ckpt
# 35/35 [==============================] - 1s 16ms/step - loss: 0.0016 - mae: 0.0369 - val_loss: 8.0696e-04 - val_mae: 0.0293
# Epoch 26/100
# 31/35 [=========================>....] - ETA: 0s - loss: 0.0016 - mae: 0.0366
# Epoch 00026: val_mae improved from 0.02925 to 0.02903, saving model to model/my_checkpoint.ckpt
# 35/35 [==============================] - 1s 17ms/step - loss: 0.0016 - mae: 0.0366 - val_loss: 7.9850e-04 - val_mae: 0.0290
# Epoch 27/100
# 33/35 [===========================>..] - ETA: 0s - loss: 0.0015 - mae: 0.0351
# Epoch 00027: val_mae improved from 0.02903 to 0.02884, saving model to model/my_checkpoint.ckpt
# 35/35 [==============================] - 1s 16ms/step - loss: 0.0015 - mae: 0.0364 - val_loss: 7.9114e-04 - val_mae: 0.0288
# Epoch 28/100
# 32/35 [==========================>...] - ETA: 0s - loss: 0.0015 - mae: 0.0354
# Epoch 00028: val_mae improved from 0.02884 to 0.02868, saving model to model/my_checkpoint.ckpt
# 35/35 [==============================] - 1s 16ms/step - loss: 0.0015 - mae: 0.0361 - val_loss: 7.8490e-04 - val_mae: 0.0287
# Epoch 29/100
# 33/35 [===========================>..] - ETA: 0s - loss: 0.0015 - mae: 0.0346
# Epoch 00029: val_mae improved from 0.02868 to 0.02855, saving model to model/my_checkpoint.ckpt
# 35/35 [==============================] - 1s 16ms/step - loss: 0.0015 - mae: 0.0359 - val_loss: 7.7952e-04 - val_mae: 0.0286
# Epoch 30/100
# 33/35 [===========================>..] - ETA: 0s - loss: 0.0015 - mae: 0.0344
# Epoch 00030: val_mae improved from 0.02855 to 0.02844, saving model to model/my_checkpoint.ckpt
# 35/35 [==============================] - 1s 16ms/step - loss: 0.0015 - mae: 0.0357 - val_loss: 7.7488e-04 - val_mae: 0.0284
# Epoch 31/100
# 35/35 [==============================] - ETA: 0s - loss: 0.0015 - mae: 0.0355
# Epoch 00031: val_mae improved from 0.02844 to 0.02836, saving model to model/my_checkpoint.ckpt
# 35/35 [==============================] - 1s 17ms/step - loss: 0.0015 - mae: 0.0355 - val_loss: 7.7086e-04 - val_mae: 0.0284
# Epoch 32/100
# 33/35 [===========================>..] - ETA: 0s - loss: 0.0014 - mae: 0.0340
# Epoch 00032: val_mae improved from 0.02836 to 0.02828, saving model to model/my_checkpoint.ckpt
# 35/35 [==============================] - 1s 16ms/step - loss: 0.0015 - mae: 0.0354 - val_loss: 7.6737e-04 - val_mae: 0.0283
# Epoch 33/100
# 35/35 [==============================] - ETA: 0s - loss: 0.0015 - mae: 0.0352
# Epoch 00033: val_mae improved from 0.02828 to 0.02822, saving model to model/my_checkpoint.ckpt
# 35/35 [==============================] - 1s 16ms/step - loss: 0.0015 - mae: 0.0352 - val_loss: 7.6438e-04 - val_mae: 0.0282
# Epoch 34/100
# 35/35 [==============================] - ETA: 0s - loss: 0.0015 - mae: 0.0350
# Epoch 00034: val_mae improved from 0.02822 to 0.02817, saving model to model/my_checkpoint.ckpt
# 35/35 [==============================] - 1s 17ms/step - loss: 0.0015 - mae: 0.0350 - val_loss: 7.6180e-04 - val_mae: 0.0282
# Epoch 35/100
# 32/35 [==========================>...] - ETA: 0s - loss: 0.0014 - mae: 0.0340
# Epoch 00035: val_mae improved from 0.02817 to 0.02813, saving model to model/my_checkpoint.ckpt
# 35/35 [==============================] - 1s 16ms/step - loss: 0.0015 - mae: 0.0349 - val_loss: 7.5958e-04 - val_mae: 0.0281
# Epoch 36/100
# 33/35 [===========================>..] - ETA: 0s - loss: 0.0014 - mae: 0.0333
# Epoch 00036: val_mae improved from 0.02813 to 0.02809, saving model to model/my_checkpoint.ckpt
# 35/35 [==============================] - 1s 16ms/step - loss: 0.0015 - mae: 0.0347 - val_loss: 7.5762e-04 - val_mae: 0.0281
# Epoch 37/100
# 31/35 [=========================>....] - ETA: 0s - loss: 0.0015 - mae: 0.0343
# Epoch 00037: val_mae improved from 0.02809 to 0.02807, saving model to model/my_checkpoint.ckpt
# 35/35 [==============================] - 1s 17ms/step - loss: 0.0015 - mae: 0.0346 - val_loss: 7.5590e-04 - val_mae: 0.0281
# Epoch 38/100
# 32/35 [==========================>...] - ETA: 0s - loss: 0.0014 - mae: 0.0335
# Epoch 00038: val_mae improved from 0.02807 to 0.02805, saving model to model/my_checkpoint.ckpt
# 35/35 [==============================] - 1s 16ms/step - loss: 0.0015 - mae: 0.0344 - val_loss: 7.5441e-04 - val_mae: 0.0281
# Epoch 39/100
# 31/35 [=========================>....] - ETA: 0s - loss: 0.0015 - mae: 0.0339
# Epoch 00039: val_mae improved from 0.02805 to 0.02804, saving model to model/my_checkpoint.ckpt
# 35/35 [==============================] - 1s 16ms/step - loss: 0.0015 - mae: 0.0343 - val_loss: 7.5313e-04 - val_mae: 0.0280
# Epoch 40/100
# 33/35 [===========================>..] - ETA: 0s - loss: 0.0014 - mae: 0.0326
# Epoch 00040: val_mae improved from 0.02804 to 0.02804, saving model to model/my_checkpoint.ckpt
# 35/35 [==============================] - 1s 15ms/step - loss: 0.0014 - mae: 0.0342 - val_loss: 7.5203e-04 - val_mae: 0.0280
# Epoch 41/100
# 32/35 [==========================>...] - ETA: 0s - loss: 0.0014 - mae: 0.0330
# Epoch 00041: val_mae did not improve from 0.02804
# 35/35 [==============================] - 1s 15ms/step - loss: 0.0014 - mae: 0.0340 - val_loss: 7.5132e-04 - val_mae: 0.0280
# Epoch 42/100
# 32/35 [==========================>...] - ETA: 0s - loss: 0.0014 - mae: 0.0329
# Epoch 00042: val_mae did not improve from 0.02804
# 35/35 [==============================] - 1s 15ms/step - loss: 0.0014 - mae: 0.0339 - val_loss: 7.5123e-04 - val_mae: 0.0281
# Epoch 43/100
# 35/35 [==============================] - ETA: 0s - loss: 0.0014 - mae: 0.0338
# Epoch 00043: val_mae did not improve from 0.02804
# 35/35 [==============================] - 1s 16ms/step - loss: 0.0014 - mae: 0.0338 - val_loss: 7.5063e-04 - val_mae: 0.0281
# Epoch 44/100
# 32/35 [==========================>...] - ETA: 0s - loss: 0.0014 - mae: 0.0326
# Epoch 00044: val_mae did not improve from 0.02804
# 35/35 [==============================] - 1s 15ms/step - loss: 0.0014 - mae: 0.0336 - val_loss: 7.5046e-04 - val_mae: 0.0281
# Epoch 45/100
# 34/35 [============================>.] - ETA: 0s - loss: 0.0014 - mae: 0.0332
# Epoch 00045: val_mae did not improve from 0.02804
# 35/35 [==============================] - 1s 15ms/step - loss: 0.0014 - mae: 0.0335 - val_loss: 7.5030e-04 - val_mae: 0.0281
# Epoch 46/100
# 31/35 [=========================>....] - ETA: 0s - loss: 0.0014 - mae: 0.0329
# Epoch 00046: val_mae did not improve from 0.02804
# 35/35 [==============================] - 1s 15ms/step - loss: 0.0014 - mae: 0.0334 - val_loss: 7.5018e-04 - val_mae: 0.0281
# Epoch 47/100
# 32/35 [==========================>...] - ETA: 0s - loss: 0.0014 - mae: 0.0321
# Epoch 00047: val_mae did not improve from 0.02804
# 35/35 [==============================] - 1s 15ms/step - loss: 0.0014 - mae: 0.0333 - val_loss: 7.5019e-04 - val_mae: 0.0282
# Epoch 48/100
# 33/35 [===========================>..] - ETA: 0s - loss: 0.0013 - mae: 0.0315
# Epoch 00048: val_mae did not improve from 0.02804
# 35/35 [==============================] - 1s 15ms/step - loss: 0.0014 - mae: 0.0332 - val_loss: 7.5012e-04 - val_mae: 0.0282
# Epoch 49/100
# 32/35 [==========================>...] - ETA: 0s - loss: 0.0014 - mae: 0.0319
# Epoch 00049: val_mae did not improve from 0.02804
# 35/35 [==============================] - 1s 15ms/step - loss: 0.0014 - mae: 0.0331 - val_loss: 7.5019e-04 - val_mae: 0.0282
# Epoch 50/100
# 33/35 [===========================>..] - ETA: 0s - loss: 0.0013 - mae: 0.0313
# Epoch 00050: val_mae did not improve from 0.02804
# 35/35 [==============================] - 1s 15ms/step - loss: 0.0014 - mae: 0.0330 - val_loss: 7.5009e-04 - val_mae: 0.0282
# Epoch 51/100
# 31/35 [=========================>....] - ETA: 0s - loss: 0.0014 - mae: 0.0323
# Epoch 00051: val_mae did not improve from 0.02804
# 35/35 [==============================] - 1s 15ms/step - loss: 0.0014 - mae: 0.0329 - val_loss: 7.5031e-04 - val_mae: 0.0282
# Epoch 52/100
# 34/35 [============================>.] - ETA: 0s - loss: 0.0014 - mae: 0.0324
# Epoch 00052: val_mae did not improve from 0.02804
# 35/35 [==============================] - 1s 16ms/step - loss: 0.0014 - mae: 0.0328 - val_loss: 7.5039e-04 - val_mae: 0.0283
# Epoch 53/100
# 31/35 [=========================>....] - ETA: 0s - loss: 0.0014 - mae: 0.0321
# Epoch 00053: val_mae did not improve from 0.02804
# 35/35 [==============================] - 1s 15ms/step - loss: 0.0014 - mae: 0.0327 - val_loss: 7.5075e-04 - val_mae: 0.0283
# Epoch 54/100
# 32/35 [==========================>...] - ETA: 0s - loss: 0.0013 - mae: 0.0314
# Epoch 00054: val_mae did not improve from 0.02804
# 35/35 [==============================] - 1s 16ms/step - loss: 0.0014 - mae: 0.0327 - val_loss: 7.5121e-04 - val_mae: 0.0283
# Epoch 55/100
# 32/35 [==========================>...] - ETA: 0s - loss: 0.0013 - mae: 0.0313
# Epoch 00055: val_mae did not improve from 0.02804
# 35/35 [==============================] - 1s 15ms/step - loss: 0.0014 - mae: 0.0326 - val_loss: 7.5129e-04 - val_mae: 0.0283
# Epoch 56/100
# 34/35 [============================>.] - ETA: 0s - loss: 0.0014 - mae: 0.0321
# Epoch 00056: val_mae did not improve from 0.02804
# 35/35 [==============================] - 1s 15ms/step - loss: 0.0014 - mae: 0.0325 - val_loss: 7.5180e-04 - val_mae: 0.0284
# Epoch 57/100
# 32/35 [==========================>...] - ETA: 0s - loss: 0.0013 - mae: 0.0312
# Epoch 00057: val_mae did not improve from 0.02804
# 35/35 [==============================] - 1s 15ms/step - loss: 0.0014 - mae: 0.0324 - val_loss: 7.5225e-04 - val_mae: 0.0284
# Epoch 58/100
# 31/35 [=========================>....] - ETA: 0s - loss: 0.0014 - mae: 0.0316
# Epoch 00058: val_mae did not improve from 0.02804
# 35/35 [==============================] - 1s 15ms/step - loss: 0.0014 - mae: 0.0324 - val_loss: 7.5254e-04 - val_mae: 0.0284
# Epoch 59/100
# 33/35 [===========================>..] - ETA: 0s - loss: 0.0013 - mae: 0.0305
# Epoch 00059: val_mae did not improve from 0.02804
# 35/35 [==============================] - 1s 15ms/step - loss: 0.0014 - mae: 0.0323 - val_loss: 7.5308e-04 - val_mae: 0.0285
# Epoch 60/100
# 35/35 [==============================] - ETA: 0s - loss: 0.0014 - mae: 0.0323
# Epoch 00060: val_mae did not improve from 0.02804
# 35/35 [==============================] - 1s 15ms/step - loss: 0.0014 - mae: 0.0323 - val_loss: 7.5356e-04 - val_mae: 0.0285
# Epoch 61/100
# 32/35 [==========================>...] - ETA: 0s - loss: 0.0013 - mae: 0.0309
# Epoch 00061: val_mae did not improve from 0.02804
# 35/35 [==============================] - 1s 15ms/step - loss: 0.0014 - mae: 0.0322 - val_loss: 7.5412e-04 - val_mae: 0.0285
# Epoch 62/100
# 31/35 [=========================>....] - ETA: 0s - loss: 0.0014 - mae: 0.0314
# Epoch 00062: val_mae did not improve from 0.02804
# 35/35 [==============================] - 1s 15ms/step - loss: 0.0014 - mae: 0.0322 - val_loss: 7.5454e-04 - val_mae: 0.0286
# Epoch 63/100
# 31/35 [=========================>....] - ETA: 0s - loss: 0.0014 - mae: 0.0313
# Epoch 00063: val_mae did not improve from 0.02804
# 35/35 [==============================] - 1s 15ms/step - loss: 0.0014 - mae: 0.0321 - val_loss: 7.5495e-04 - val_mae: 0.0286
# Epoch 64/100
# 32/35 [==========================>...] - ETA: 0s - loss: 0.0013 - mae: 0.0308
# Epoch 00064: val_mae did not improve from 0.02804
# 35/35 [==============================] - 1s 15ms/step - loss: 0.0014 - mae: 0.0321 - val_loss: 7.5536e-04 - val_mae: 0.0286
# Epoch 65/100
# 32/35 [==========================>...] - ETA: 0s - loss: 0.0013 - mae: 0.0307
# Epoch 00065: val_mae did not improve from 0.02804
# 35/35 [==============================] - 1s 16ms/step - loss: 0.0014 - mae: 0.0320 - val_loss: 7.5585e-04 - val_mae: 0.0286
# Epoch 66/100
# 31/35 [=========================>....] - ETA: 0s - loss: 0.0013 - mae: 0.0312
# Epoch 00066: val_mae did not improve from 0.02804
# 35/35 [==============================] - 1s 15ms/step - loss: 0.0014 - mae: 0.0320 - val_loss: 7.5619e-04 - val_mae: 0.0287
# Epoch 67/100
# 34/35 [============================>.] - ETA: 0s - loss: 0.0014 - mae: 0.0314
# Epoch 00067: val_mae did not improve from 0.02804
# 35/35 [==============================] - 1s 16ms/step - loss: 0.0014 - mae: 0.0319 - val_loss: 7.5687e-04 - val_mae: 0.0287
# Epoch 68/100
# 31/35 [=========================>....] - ETA: 0s - loss: 0.0013 - mae: 0.0311
# Epoch 00068: val_mae did not improve from 0.02804
# 35/35 [==============================] - 1s 15ms/step - loss: 0.0014 - mae: 0.0319 - val_loss: 7.5716e-04 - val_mae: 0.0287
# Epoch 69/100
# 35/35 [==============================] - ETA: 0s - loss: 0.0014 - mae: 0.0319
# Epoch 00069: val_mae did not improve from 0.02804
# 35/35 [==============================] - 1s 15ms/step - loss: 0.0014 - mae: 0.0319 - val_loss: 7.5760e-04 - val_mae: 0.0287
# Epoch 70/100
# 32/35 [==========================>...] - ETA: 0s - loss: 0.0013 - mae: 0.0305
# Epoch 00070: val_mae did not improve from 0.02804
# 35/35 [==============================] - 1s 15ms/step - loss: 0.0014 - mae: 0.0318 - val_loss: 7.5806e-04 - val_mae: 0.0288
# Epoch 71/100
# 31/35 [=========================>....] - ETA: 0s - loss: 0.0013 - mae: 0.0309
# Epoch 00071: val_mae did not improve from 0.02804
# 35/35 [==============================] - 1s 16ms/step - loss: 0.0014 - mae: 0.0318 - val_loss: 7.5843e-04 - val_mae: 0.0288
# Epoch 72/100
# 32/35 [==========================>...] - ETA: 0s - loss: 0.0013 - mae: 0.0304
# Epoch 00072: val_mae did not improve from 0.02804
# 35/35 [==============================] - 1s 15ms/step - loss: 0.0013 - mae: 0.0318 - val_loss: 7.5872e-04 - val_mae: 0.0288
# Epoch 73/100
# 35/35 [==============================] - ETA: 0s - loss: 0.0013 - mae: 0.0317
# Epoch 00073: val_mae did not improve from 0.02804
# 35/35 [==============================] - 1s 15ms/step - loss: 0.0013 - mae: 0.0317 - val_loss: 7.5902e-04 - val_mae: 0.0288
# Epoch 74/100
# 35/35 [==============================] - ETA: 0s - loss: 0.0013 - mae: 0.0317
# Epoch 00074: val_mae did not improve from 0.02804
# 35/35 [==============================] - 1s 16ms/step - loss: 0.0013 - mae: 0.0317 - val_loss: 7.5942e-04 - val_mae: 0.0288
# Epoch 75/100
# 31/35 [=========================>....] - ETA: 0s - loss: 0.0013 - mae: 0.0308
# Epoch 00075: val_mae did not improve from 0.02804
# 35/35 [==============================] - 1s 16ms/step - loss: 0.0013 - mae: 0.0317 - val_loss: 7.5949e-04 - val_mae: 0.0289
# Epoch 76/100
# 33/35 [===========================>..] - ETA: 0s - loss: 0.0013 - mae: 0.0298
# Epoch 00076: val_mae did not improve from 0.02804
# 35/35 [==============================] - 1s 15ms/step - loss: 0.0013 - mae: 0.0317 - val_loss: 7.5972e-04 - val_mae: 0.0289
# Epoch 77/100
# 35/35 [==============================] - ETA: 0s - loss: 0.0013 - mae: 0.0316
# Epoch 00077: val_mae did not improve from 0.02804
# 35/35 [==============================] - 1s 15ms/step - loss: 0.0013 - mae: 0.0316 - val_loss: 7.6007e-04 - val_mae: 0.0289
# Epoch 78/100
# 32/35 [==========================>...] - ETA: 0s - loss: 0.0013 - mae: 0.0302
# Epoch 00078: val_mae did not improve from 0.02804
# 35/35 [==============================] - 1s 15ms/step - loss: 0.0013 - mae: 0.0316 - val_loss: 7.6019e-04 - val_mae: 0.0289
# Epoch 79/100
# 35/35 [==============================] - ETA: 0s - loss: 0.0013 - mae: 0.0316
# Epoch 00079: val_mae did not improve from 0.02804
# 35/35 [==============================] - 1s 15ms/step - loss: 0.0013 - mae: 0.0316 - val_loss: 7.6053e-04 - val_mae: 0.0289
# Epoch 80/100
# 31/35 [=========================>....] - ETA: 0s - loss: 0.0013 - mae: 0.0306
# Epoch 00080: val_mae did not improve from 0.02804
# 35/35 [==============================] - 1s 15ms/step - loss: 0.0013 - mae: 0.0315 - val_loss: 7.6061e-04 - val_mae: 0.0289
# Epoch 81/100
# 34/35 [============================>.] - ETA: 0s - loss: 0.0013 - mae: 0.0310
# Epoch 00081: val_mae did not improve from 0.02804
# 35/35 [==============================] - 1s 15ms/step - loss: 0.0013 - mae: 0.0315 - val_loss: 7.6084e-04 - val_mae: 0.0289
# Epoch 82/100
# 33/35 [===========================>..] - ETA: 0s - loss: 0.0012 - mae: 0.0296
# Epoch 00082: val_mae did not improve from 0.02804
# 35/35 [==============================] - 1s 15ms/step - loss: 0.0013 - mae: 0.0315 - val_loss: 7.6086e-04 - val_mae: 0.0289
# Epoch 83/100
# 35/35 [==============================] - ETA: 0s - loss: 0.0013 - mae: 0.0315
# Epoch 00083: val_mae did not improve from 0.02804
# 35/35 [==============================] - 1s 15ms/step - loss: 0.0013 - mae: 0.0315 - val_loss: 7.6114e-04 - val_mae: 0.0290
# Epoch 84/100
# 31/35 [=========================>....] - ETA: 0s - loss: 0.0013 - mae: 0.0305
# Epoch 00084: val_mae did not improve from 0.02804
# 35/35 [==============================] - 1s 15ms/step - loss: 0.0013 - mae: 0.0314 - val_loss: 7.6102e-04 - val_mae: 0.0290
# Epoch 85/100
# 34/35 [============================>.] - ETA: 0s - loss: 0.0013 - mae: 0.0308
# Epoch 00085: val_mae did not improve from 0.02804
# 35/35 [==============================] - 1s 16ms/step - loss: 0.0013 - mae: 0.0314 - val_loss: 7.6127e-04 - val_mae: 0.0290
# Epoch 86/100
# 35/35 [==============================] - ETA: 0s - loss: 0.0013 - mae: 0.0314
# Epoch 00086: val_mae did not improve from 0.02804
# 35/35 [==============================] - 1s 15ms/step - loss: 0.0013 - mae: 0.0314 - val_loss: 7.6120e-04 - val_mae: 0.0290
# Epoch 87/100
# 31/35 [=========================>....] - ETA: 0s - loss: 0.0013 - mae: 0.0304
# Epoch 00087: val_mae did not improve from 0.02804
# 35/35 [==============================] - 1s 15ms/step - loss: 0.0013 - mae: 0.0314 - val_loss: 7.6141e-04 - val_mae: 0.0290
# Epoch 88/100
# 32/35 [==========================>...] - ETA: 0s - loss: 0.0013 - mae: 0.0299
# Epoch 00088: val_mae did not improve from 0.02804
# 35/35 [==============================] - 1s 15ms/step - loss: 0.0013 - mae: 0.0313 - val_loss: 7.6126e-04 - val_mae: 0.0290
# Epoch 89/100
# 35/35 [==============================] - ETA: 0s - loss: 0.0013 - mae: 0.0313
# Epoch 00089: val_mae did not improve from 0.02804
# 35/35 [==============================] - 1s 16ms/step - loss: 0.0013 - mae: 0.0313 - val_loss: 7.6151e-04 - val_mae: 0.0290
# Epoch 90/100
# 33/35 [===========================>..] - ETA: 0s - loss: 0.0012 - mae: 0.0294
# Epoch 00090: val_mae did not improve from 0.02804
# 35/35 [==============================] - 1s 15ms/step - loss: 0.0013 - mae: 0.0313 - val_loss: 7.6129e-04 - val_mae: 0.0290
# Epoch 91/100
# 34/35 [============================>.] - ETA: 0s - loss: 0.0013 - mae: 0.0307
# Epoch 00091: val_mae did not improve from 0.02804
# 35/35 [==============================] - 1s 16ms/step - loss: 0.0013 - mae: 0.0313 - val_loss: 7.6116e-04 - val_mae: 0.0290
# Epoch 92/100
# 34/35 [============================>.] - ETA: 0s - loss: 0.0013 - mae: 0.0307
# Epoch 00092: val_mae did not improve from 0.02804
# 35/35 [==============================] - 1s 16ms/step - loss: 0.0013 - mae: 0.0313 - val_loss: 7.6117e-04 - val_mae: 0.0290
# Epoch 93/100
# 31/35 [=========================>....] - ETA: 0s - loss: 0.0013 - mae: 0.0302
# Epoch 00093: val_mae did not improve from 0.02804
# 35/35 [==============================] - 1s 15ms/step - loss: 0.0013 - mae: 0.0312 - val_loss: 7.6095e-04 - val_mae: 0.0290
# Epoch 94/100
# 31/35 [=========================>....] - ETA: 0s - loss: 0.0013 - mae: 0.0302
# Epoch 00094: val_mae did not improve from 0.02804
# 35/35 [==============================] - 1s 16ms/step - loss: 0.0013 - mae: 0.0312 - val_loss: 7.6090e-04 - val_mae: 0.0290
# Epoch 95/100
# 32/35 [==========================>...] - ETA: 0s - loss: 0.0013 - mae: 0.0297
# Epoch 00095: val_mae did not improve from 0.02804
# 35/35 [==============================] - 1s 15ms/step - loss: 0.0013 - mae: 0.0312 - val_loss: 7.6060e-04 - val_mae: 0.0290
# Epoch 96/100
# 31/35 [=========================>....] - ETA: 0s - loss: 0.0013 - mae: 0.0302
# Epoch 00096: val_mae did not improve from 0.02804
# 35/35 [==============================] - 1s 16ms/step - loss: 0.0013 - mae: 0.0312 - val_loss: 7.6055e-04 - val_mae: 0.0290
# Epoch 97/100
# 34/35 [============================>.] - ETA: 0s - loss: 0.0013 - mae: 0.0305
# Epoch 00097: val_mae did not improve from 0.02804
# 35/35 [==============================] - 1s 16ms/step - loss: 0.0013 - mae: 0.0311 - val_loss: 7.6025e-04 - val_mae: 0.0290
# Epoch 98/100
# 35/35 [==============================] - ETA: 0s - loss: 0.0013 - mae: 0.0311
# Epoch 00098: val_mae did not improve from 0.02804
# 35/35 [==============================] - 1s 16ms/step - loss: 0.0013 - mae: 0.0311 - val_loss: 7.6007e-04 - val_mae: 0.0290
# Epoch 99/100
# 35/35 [==============================] - ETA: 0s - loss: 0.0013 - mae: 0.0311
# Epoch 00099: val_mae did not improve from 0.02804
# 35/35 [==============================] - 1s 16ms/step - loss: 0.0013 - mae: 0.0311 - val_loss: 7.5964e-04 - val_mae: 0.0290
# Epoch 100/100
# 32/35 [==========================>...] - ETA: 0s - loss: 0.0012 - mae: 0.0296
# Epoch 00100: val_mae did not improve from 0.02804
# 35/35 [==============================] - 1s 15ms/step - loss: 0.0013 - mae: 0.0311 - val_loss: 7.5957e-04 - val_mae: 0.0290

# %%
model.load_weights(checkpoint_path)
