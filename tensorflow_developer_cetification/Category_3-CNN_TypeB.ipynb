# %%
import tensorflow_datasets as tfds
import tensorflow as tf

from tensorflow.keras.layers import Dense, Conv2D, MaxPooling2D, Flatten, Dropout
from tensorflow.keras.models import Sequential
from tensorflow.keras.callbacks import ModelCheckpoint
from tensorflow.keras.applications.vgg16 import VGG16

# %%
dataset_name = 'cats_vs_dogs'

# 처음 80%의 데이터만 사용
train_dataset = tfds.load(name=dataset_name, split='train[:80%]')

# 최근 20%의 데이터만 사용
valid_dataset = tfds.load(name=dataset_name, split='train[80%:]')

# %%
def preprocess(data):
    # x, y 데이터를 정의합니다.
    x = data['image']
    y = data['label']
    # image 정규화(Normalization)
    x = x / 255
    # 사이즈를 (224, 224)로 변환합니다.
    x = tf.image.resize(x, size=(224, 224))
    # x, y  데이터를 return 합니다.
    return x, y

# %%
batch_size=32

# %%
train_data = train_dataset.map(preprocess).batch(batch_size)
valid_data = valid_dataset.map(preprocess).batch(batch_size)

# %%
model = Sequential([
    Conv2D(64, (3, 3), input_shape=(224, 224, 3), activation='relu'),
    MaxPooling2D(2, 2),
    Conv2D(64, (3, 3), activation='relu'),
    MaxPooling2D(2, 2),
    Conv2D(128, (3, 3), activation='relu'),
    MaxPooling2D(2, 2),
    Conv2D(128, (3, 3), activation='relu'),
    MaxPooling2D(2, 2),
    Conv2D(256, (3, 3), activation='relu'),
    MaxPooling2D(2, 2),
    Flatten(),
    Dropout(0.5),
    Dense(512, activation='relu'),
    Dense(128, activation='relu'),
    Dense(2, activation='softmax'),
])
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_5 (Conv2D)           (None, 222, 222, 64)      1792
#
#  max_pooling2d_5 (MaxPooling  (None, 111, 111, 64)     0
#  2D)
#
#  conv2d_6 (Conv2D)           (None, 109, 109, 64)      36928
#
#  max_pooling2d_6 (MaxPooling  (None, 54, 54, 64)       0
#  2D)
#
#  conv2d_7 (Conv2D)           (None, 52, 52, 128)       73856
#
#  max_pooling2d_7 (MaxPooling  (None, 26, 26, 128)      0
#  2D)
#
#  conv2d_8 (Conv2D)           (None, 24, 24, 128)       147584
#
#  max_pooling2d_8 (MaxPooling  (None, 12, 12, 128)      0
#  2D)
#
#  conv2d_9 (Conv2D)           (None, 10, 10, 256)       295168
#
#  max_pooling2d_9 (MaxPooling  (None, 5, 5, 256)        0
#  2D)
#
#  flatten_1 (Flatten)         (None, 6400)              0
#
#  dropout_1 (Dropout)         (None, 6400)              0
#
#  dense_3 (Dense)             (None, 512)               3277312
#
#  dense_4 (Dense)             (None, 128)               65664
#
#  dense_5 (Dense)             (None, 2)                 258
#
# =================================================================
# Total params: 3,898,562
# Trainable params: 3,898,562
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Transfer Learning
transfer_model = VGG16(weights='imagenet', include_top=False, input_shape=(224, 224, 3))
transfer_model.trainable=False

model = Sequential([
    transfer_model,
    Flatten(),
    Dropout(0.5),
    Dense(512, activation='relu'),
    Dense(128, activation='relu'),
    Dense(2, activation='softmax'),
])
model.summary()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg16/vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5
# 58892288/58889256 [==============================] - 1s 0us/step
# 58900480/58889256 [==============================] - 1s 0us/step
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  vgg16 (Functional)          (None, 7, 7, 512)         14714688
#
#  flatten_2 (Flatten)         (None, 25088)             0
#
#  dropout_2 (Dropout)         (None, 25088)             0
#
#  dense_6 (Dense)             (None, 512)               12845568
#
#  dense_7 (Dense)             (None, 128)               65664
#
#  dense_8 (Dense)             (None, 2)                 258
#
# =================================================================
# Total params: 27,626,178
# Trainable params: 12,911,490
# Non-trainable params: 14,714,688
# _________________________________________________________________

# %%
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['acc'])

# %%
checkpoint_path = "my_checkpoint.ckpt"
checkpoint = ModelCheckpoint(filepath=checkpoint_path, 
                             save_weights_only=True, 
                             save_best_only=True, 
                             monitor='val_loss', 
                             verbose=1)

# %%
model.fit(train_data,
          validation_data=(valid_data),
          epochs=20,
          callbacks=[checkpoint],
          )
# Out:
# Epoch 1/20
# 582/582 [==============================] - ETA: 0s - loss: 0.3039 - acc: 0.8844
# Epoch 00001: val_loss improved from inf to 0.19076, saving model to my_checkpoint.ckpt
# 582/582 [==============================] - 215s 332ms/step - loss: 0.3039 - acc: 0.8844 - val_loss: 0.1908 - val_acc: 0.9213
# Epoch 2/20
# 582/582 [==============================] - ETA: 0s - loss: 0.1806 - acc: 0.9251
# Epoch 00002: val_loss improved from 0.19076 to 0.15858, saving model to my_checkpoint.ckpt
# 582/582 [==============================] - 182s 313ms/step - loss: 0.1806 - acc: 0.9251 - val_loss: 0.1586 - val_acc: 0.9304
# Epoch 3/20
# 582/582 [==============================] - ETA: 0s - loss: 0.1618 - acc: 0.9327
# Epoch 00003: val_loss did not improve from 0.15858
# 582/582 [==============================] - 182s 312ms/step - loss: 0.1618 - acc: 0.9327 - val_loss: 0.1823 - val_acc: 0.9250
# Epoch 4/20
# 582/582 [==============================] - ETA: 0s - loss: 0.1521 - acc: 0.9353
# Epoch 00004: val_loss did not improve from 0.15858
# 582/582 [==============================] - 182s 312ms/step - loss: 0.1521 - acc: 0.9353 - val_loss: 0.1626 - val_acc: 0.9299
# Epoch 5/20
# 582/582 [==============================] - ETA: 0s - loss: 0.1386 - acc: 0.9431
# Epoch 00005: val_loss did not improve from 0.15858
# 582/582 [==============================] - 182s 312ms/step - loss: 0.1386 - acc: 0.9431 - val_loss: 0.1809 - val_acc: 0.9314
# Epoch 6/20
# 582/582 [==============================] - ETA: 0s - loss: 0.1242 - acc: 0.9497
# Epoch 00006: val_loss did not improve from 0.15858
# 582/582 [==============================] - 182s 312ms/step - loss: 0.1242 - acc: 0.9497 - val_loss: 0.1620 - val_acc: 0.9306
# Epoch 7/20
# 582/582 [==============================] - ETA: 0s - loss: 0.1123 - acc: 0.9535
# Epoch 00007: val_loss did not improve from 0.15858
# 582/582 [==============================] - 181s 311ms/step - loss: 0.1123 - acc: 0.9535 - val_loss: 0.1746 - val_acc: 0.9286
# Epoch 8/20
# 582/582 [==============================] - ETA: 0s - loss: 0.1112 - acc: 0.9543
# Epoch 00008: val_loss did not improve from 0.15858
# 582/582 [==============================] - 181s 312ms/step - loss: 0.1112 - acc: 0.9543 - val_loss: 0.1712 - val_acc: 0.9325
# Epoch 9/20
# 582/582 [==============================] - ETA: 0s - loss: 0.0957 - acc: 0.9617
# Epoch 00009: val_loss did not improve from 0.15858
# 582/582 [==============================] - 181s 311ms/step - loss: 0.0957 - acc: 0.9617 - val_loss: 0.1787 - val_acc: 0.9269
# Epoch 10/20
# 582/582 [==============================] - ETA: 0s - loss: 0.0864 - acc: 0.9654
# Epoch 00010: val_loss did not improve from 0.15858
# 582/582 [==============================] - 182s 312ms/step - loss: 0.0864 - acc: 0.9654 - val_loss: 0.1804 - val_acc: 0.9321
# Epoch 11/20
# 582/582 [==============================] - ETA: 0s - loss: 0.0873 - acc: 0.9651
# Epoch 00011: val_loss did not improve from 0.15858
# 582/582 [==============================] - 182s 312ms/step - loss: 0.0873 - acc: 0.9651 - val_loss: 0.1830 - val_acc: 0.9286
# Epoch 12/20
# 582/582 [==============================] - ETA: 0s - loss: 0.0831 - acc: 0.9665
# Epoch 00012: val_loss did not improve from 0.15858
# 582/582 [==============================] - 182s 312ms/step - loss: 0.0831 - acc: 0.9665 - val_loss: 0.2147 - val_acc: 0.9091
# Epoch 13/20
# 582/582 [==============================] - ETA: 0s - loss: 0.0860 - acc: 0.9651
# Epoch 00013: val_loss did not improve from 0.15858
# 582/582 [==============================] - 182s 312ms/step - loss: 0.0860 - acc: 0.9651 - val_loss: 0.2827 - val_acc: 0.9035
# Epoch 14/20
# 582/582 [==============================] - ETA: 0s - loss: 0.0712 - acc: 0.9726
# Epoch 00014: val_loss did not improve from 0.15858
# 582/582 [==============================] - 181s 312ms/step - loss: 0.0712 - acc: 0.9726 - val_loss: 0.1917 - val_acc: 0.9280
# Epoch 15/20
# 582/582 [==============================] - ETA: 0s - loss: 0.0633 - acc: 0.9746
# Epoch 00015: val_loss did not improve from 0.15858
# 582/582 [==============================] - 182s 312ms/step - loss: 0.0633 - acc: 0.9746 - val_loss: 0.2885 - val_acc: 0.9166
# Epoch 16/20
# 582/582 [==============================] - ETA: 0s - loss: 0.0667 - acc: 0.9742
# Epoch 00016: val_loss did not improve from 0.15858
# 582/582 [==============================] - 181s 312ms/step - loss: 0.0667 - acc: 0.9742 - val_loss: 0.2593 - val_acc: 0.9200
# Epoch 17/20
# 582/582 [==============================] - ETA: 0s - loss: 0.0615 - acc: 0.9759
# Epoch 00017: val_loss did not improve from 0.15858
# 582/582 [==============================] - 182s 312ms/step - loss: 0.0615 - acc: 0.9759 - val_loss: 0.2339 - val_acc: 0.9267
# Epoch 18/20
# 582/582 [==============================] - ETA: 0s - loss: 0.0524 - acc: 0.9803
# Epoch 00018: val_loss did not improve from 0.15858
# 582/582 [==============================] - 181s 311ms/step - loss: 0.0524 - acc: 0.9803 - val_loss: 0.2482 - val_acc: 0.9194
# Epoch 19/20
# 582/582 [==============================] - ETA: 0s - loss: 0.0517 - acc: 0.9810
# Epoch 00019: val_loss did not improve from 0.15858
# 582/582 [==============================] - 181s 311ms/step - loss: 0.0517 - acc: 0.9810 - val_loss: 0.2281 - val_acc: 0.9252
# Epoch 20/20
# 582/582 [==============================] - ETA: 0s - loss: 0.0532 - acc: 0.9797
# Epoch 00020: val_loss did not improve from 0.15858
# 582/582 [==============================] - 182s 312ms/step - loss: 0.0532 - acc: 0.9797 - val_loss: 0.1756 - val_acc: 0.9316

# %%
# checkpoint 를 저장한 파일명을 입력합니다.
model.load_weights(checkpoint_path)
